# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Traning and testing for 2 days testing

# %% [markdown]
# ## CNN/LSTM/ATTENTION

# %%
test_path = '/Users/bagafoufabrice/Documents/MINES_ALES/Testloss_LSTMACNN.npy'
train_path = '/Users/bagafoufabrice/Documents/MINES_ALES/Trainloss_LSTMACNN.npy'

train_loss = np.load(train_path)


test_loss = np.load(test_path)

print('min test loss = ',test_loss.min())
print('number of epoch = ',test_loss.argmin())

plt.plot(train_loss)
plt.plot(test_loss)
plt.show()
# Out:
# min test loss =  5.274787902832031
# number of epoch =  132

# %% [markdown]
# ## CNN/LSTM

# %%
test_path = '/Users/bagafoufabrice/Documents/MINES_ALES/Testloss_LSTMCNN.npy'
train_path = '/Users/bagafoufabrice/Documents/MINES_ALES/Trainloss_LSTMCNN.npy'

train_loss = np.load(train_path)


test_loss = np.load(test_path)

print('min test loss = ',test_loss.min())
print('number of epoch = ',test_loss.argmin())

plt.plot(train_loss)
plt.plot(test_loss)
plt.show()
# Out:
# min test loss =  5.299456596374512
# number of epoch =  256

# %% [markdown]
# ## LSTM/A

# %%
test_path = '/Users/bagafoufabrice/Documents/MINES_ALES/Testloss_LSTMA.npy'
train_path = '/Users/bagafoufabrice/Documents/MINES_ALES/Trainloss_LSTMA.npy'

train_loss = np.load(train_path)


test_loss = np.load(test_path)

print('min test loss = ',test_loss.min())
print('number of epoch = ',test_loss.argmin())

plt.plot(train_loss)
plt.plot(test_loss)
plt.show()
# Out:
# min test loss =  5.286920070648193
# number of epoch =  70

# %% [markdown]
# ## LSTM

# %%
test_path = '/Users/bagafoufabrice/Documents/MINES_ALES/Testloss_LSTM.npy'
train_path = '/Users/bagafoufabrice/Documents/MINES_ALES/Trainloss_LSTM.npy'

train_loss = np.load(train_path)


test_loss = np.load(test_path)

print('min test loss = ',test_loss.min())
print('number of epoch = ',test_loss.argmin())

plt.plot(train_loss)
plt.plot(test_loss)
plt.show()
# Out:
# min test loss =  5.283074378967285
# number of epoch =  90

# %% [markdown]
# ## LTSM CNN Attention
# * layer = 5
# * hidden size = 500
# * channels CNN : 1-4, 4-1

# %%
test_path = '/Users/bagafoufabrice/Documents/MINES_ALES/Testloss_LSTMACNN2.npy'
train_path = '/Users/bagafoufabrice/Documents/MINES_ALES/Trainloss_LSTMACNN2.npy'

train_loss = np.load(train_path)


test_loss = np.load(test_path)

print('min test loss = ',test_loss.min())
print('number of epoch = ',test_loss.argmin())

plt.plot(train_loss)
plt.plot(test_loss)
plt.show()
# Out:
# min test loss =  5.2859063148498535
# number of epoch =  58
